# %% [markdown]
# # COGS 108 - Final Project Proposal

# %% [markdown]
# # Names
#
# - Shadman Noor
# - Yubi Quinzon
# - Shabab Chowdhury
# - Ittoop Shinu Shibu
# - Adelle Thompson

# %% [markdown]
# # Group Members IDs
#
# - A12960909
# - A15752301
# - A13426611
# - A13719148
# - A14083973

# %% [markdown]
# # Research Question

# %% [markdown]
# We are planning to look at music data, specifically pop genre lyrics to figure out which are the common words that are used in the most popular songs which generate the most revenue. We want to know which words contribute to the highest revenue generation in the pop genre from 2000 onwards.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# We are interested in music data because music is something that is universal and it has always been a part and parcel of most of our lives. Since all of our group members love music and are enthusiastic about doing research on this topic, we choose to go with it. We have started to look at different datasets which contain lyrics of different popular songs. We have also been looking at other data science projects related to music, for inspiration. The first link below is an example of some of the projects we have been looking at, and the second link contains an example dataset which could be useful for our project.
#
# References (include links):
# - 1) http://ds3-at-ucsd.github.io/msd-fp-p1/
# - 2) https://www.kaggle.com/gyani95/380000-lyrics-from-metrolyrics

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Our hypothesis is that the words most commonly used in popular songs play a role in making that song popular. If some words come up repeatedly in popular songs, we hypothesize that those words could be a part of the reason behind the success of those particular words.

# %% [markdown]
# # Data

# %% [markdown]
# For this project we will be working with multiple data sets. We first need a data set that will contain all the words that are frequently used in popular songs. The data set will tell us the name of the word, the frequency of the word and the frequency of the words for a particular year. Next we will look at the revenue generated by the songs which these words are associated with. This will help us identify which words are contributing to the most revenue generation.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# We will not commit any actions that will harm anyone. Our project will not harm the music industry in any way and we will ensure our project is handled privately. We will also ensure that we have permission for any dataset we use for this project and make sure to minimalize biases from our data.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# * We expect clear and timely communication from all group members.
# * We expect all group members to attend group meetings on all the assigned dates and if for some reason someone cannot attend,   we expect to be notified reasonably early.
# * We expect all of the group members to help one another and actively participate throughout the project.

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/30  |  3:45 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 2/06  |  3:45 PM  |  Do background research on topic | Discuss ideal dataset(s) and ethics |
# | 2/13  |  3:45 PM  | Search for datasets | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part |
# | 2/20  |  3:45 PM  | Import & Wrangle Data (Shinu); EDA (Shabab) | Review/Edit wrangling/EDA; Discuss Analysis Plan |
# | 2/27  |  3:45 PM  | Finalize wrangling/EDA; Begin Analysis (Adelle ; Yubi) | Discuss/edit Analysis; Complete project check-in |
# | 3/05  |  3:45 PM  | Complete analysis; Draft results/conclusion/discussion (Shadman)| Discuss/edit full project |
# | 3/13  |  3:45 PM  | Come up with further edits and work on visualization | Discuss final edits and any last minute changes |
# | 3/19  |  Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
